# %% [markdown]
# <a href="https://colab.research.google.com/github/LisaD002/Capstone-Project/blob/main/CIND820_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded =  files.upload()
# Out:
#      <input type="file" id="files-dd0712a5-9fcb-4d01-a4a0-1c6321f10bc3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dd0712a5-9fcb-4d01-a4a0-1c6321f10bc3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df2 = pd.read_csv('COVID-19_Diagnostic_Laboratory_Testing__PCR_Testing__Time_Series (3).csv')
df2.head(10)
# Out:
#   state state_name  state_fips fema_region overall_outcome        date  \
# 0    AL    Alabama           1    Region 4        Negative  2020/03/01
# 1    AL    Alabama           1    Region 4        Positive  2020/03/01
# 2    AL    Alabama           1    Region 4        Negative  2020/03/02
# 3    AL    Alabama           1    Region 4        Positive  2020/03/02
# 4    AL    Alabama           1    Region 4        Negative  2020/03/03
# 5    AL    Alabama           1    Region 4        Positive  2020/03/03
# 6    AL    Alabama           1    Region 4        Negative  2020/03/04
# 7    AL    Alabama           1    Region 4        Positive  2020/03/04
# 8    AL    Alabama           1    Region 4        Negative  2020/03/05
# 9    AL    Alabama           1    Region 4        Positive  2020/03/05
#
#    new_results_reported  total_results_reported  geocoded_state
# 0                    96                      96             NaN
# ...

# %%
df = pd.DataFrame(df2)

# %%
df2.dtypes
# Out:
# state                      object
# state_name                 object
# state_fips                  int64
# fema_region                object
# overall_outcome            object
# date                       object
# new_results_reported        int64
# total_results_reported      int64
# geocoded_state            float64
# dtype: object

# %%
df2.dropna(inplace= True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   0 non-null      object
#  1   state_name              0 non-null      object
#  2   state_fips              0 non-null      int64
#  3   fema_region             0 non-null      object
#  4   overall_outcome         0 non-null      object
#  5   date                    0 non-null      object
#  6   new_results_reported    0 non-null      int64
#  7   total_results_reported  0 non-null      int64
#  8   geocoded_state          0 non-null      float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 0.0+ bytes

# %%
df["overall_outcome"].head()
# Out:
# 0    Negative
# 1    Positive
# 2    Negative
# 3    Positive
# 4    Negative
# Name: overall_outcome, dtype: object

# %%
df.overall_outcome.head()
# Out:
# 0    Negative
# 1    Positive
# 2    Negative
# 3    Positive
# 4    Negative
# Name: overall_outcome, dtype: object

# %%
PCR_test = df[[ "overall_outcome", "new_results_reported", "total_results_reported"]]

# %%
cols = ["overall_outcome", "new_results_reported", "total_results_reported"]
PCR_list_three = PCR_test[cols]

# %%
PCR_list_three.head()
# Out:
#   overall_outcome  new_results_reported  total_results_reported
# 0        Negative                    96                      96
# 1        Positive                    16                      16
# 2        Negative                    72                     168
# 3        Positive                     6                      22
# 4        Negative                    94                     262

# %%
df.drop('geocoded_state', axis=1, inplace=True)

# %%
df.iloc[0:10, 4:7]
# Out:
#   overall_outcome        date  new_results_reported
# 0        Negative  2020/03/01                    96
# 1        Positive  2020/03/01                    16
# 2        Negative  2020/03/02                    72
# 3        Positive  2020/03/02                     6
# 4        Negative  2020/03/03                    94
# 5        Positive  2020/03/03                     9
# 6        Negative  2020/03/04                     0
# 7        Positive  2020/03/04                     2
# 8        Negative  2020/03/05                    61
# 9        Positive  2020/03/05                     6

# %%
df.set_index("overall_outcome", inplace=True)
df.head()
# Out:
#                 state state_name  state_fips fema_region        date  \
# overall_outcome
# Negative           AL    Alabama           1    Region 4  2020/03/01
# Positive           AL    Alabama           1    Region 4  2020/03/01
# Negative           AL    Alabama           1    Region 4  2020/03/02
# Positive           AL    Alabama           1    Region 4  2020/03/02
# Negative           AL    Alabama           1    Region 4  2020/03/03
#
#                  new_results_reported  total_results_reported
# overall_outcome
# Negative                           96                      96
# Positive                           16                      16
# Negative                           72                     168
# Positive                            6                      22
# Negative                           94                     262

# %%
Negative = df.loc["Negative"]

# %%
Negative.iloc[0:10, 5:6]
# Out:
#                  new_results_reported
# overall_outcome
# Negative                           96
# Negative                           72
# Negative                           94
# Negative                            0
# Negative                           61
# Negative                           12
# Negative                           20
# Negative                           94
# Negative                           58
# Negative                           84

# %%
Negative.iloc[0:10, 6:7]
# Out:
#                  total_results_reported
# overall_outcome
# Negative                             96
# Negative                            168
# Negative                            262
# Negative                            262
# Negative                            323
# Negative                            335
# Negative                            355
# Negative                            449
# Negative                            507
# Negative                            591

# %%
Positive = df.loc["Positive"]

# %%
Positive.iloc[0:10, 5:6]
# Out:
#                  new_results_reported
# overall_outcome
# Positive                           16
# Positive                            6
# Positive                            9
# Positive                            2
# Positive                            6
# Positive                            4
# Positive                            4
# Positive                           17
# Positive                            6
# Positive                            9

# %%
Positive.iloc[0:10, 6:7]
# Out:
#                  total_results_reported
# overall_outcome
# Positive                             16
# Positive                             22
# Positive                             31
# Positive                             33
# Positive                             39
# Positive                             43
# Positive                             47
# Positive                             64
# Positive                             70
# Positive                             79

# %%
Inconclusive  = df.loc["Inconclusive"]

# %%
Inconclusive.iloc[0:10, 5:6]
# Out:
#                  new_results_reported
# overall_outcome
# Inconclusive                        1
# Inconclusive                        0
# Inconclusive                        0
# Inconclusive                        0
# Inconclusive                        0
# Inconclusive                        0
# Inconclusive                        4
# Inconclusive                        1
# Inconclusive                        1
# Inconclusive                        3

# %%
Inconclusive.iloc[0:10, 6:7]
# Out:
#                  total_results_reported
# overall_outcome
# Inconclusive                          1
# Inconclusive                          1
# Inconclusive                          1
# Inconclusive                          1
# Inconclusive                          1
# Inconclusive                          1
# Inconclusive                          5
# Inconclusive                          6
# Inconclusive                          7
# Inconclusive                         10

# %%
Inconclusive.describe()
# Out:
#          state_fips  new_results_reported  total_results_reported
# count  50993.000000          50993.000000            50993.000000
# mean      31.225521             47.273567            21645.198733
# std       17.990329            182.131669            51827.121776
# min        1.000000             -7.000000                0.000000
# 25%       17.000000              2.000000             1280.000000
# 50%       30.000000             10.000000             5678.000000
# 75%       45.000000             34.000000            20144.000000
# max       78.000000           7222.000000           562355.000000

# %%
Positive.describe()
# Out:
#          state_fips  new_results_reported  total_results_reported
# count  52684.000000          52684.000000            5.268400e+04
# mean      32.082682           1763.245141            7.669924e+05
# std       18.734002           4399.259354            1.281653e+06
# min        1.000000              0.000000            0.000000e+00
# 25%       17.000000            162.000000            6.567625e+04
# 50%       31.000000            574.000000            2.982345e+05
# 75%       46.000000           1678.000000            9.379335e+05
# max       78.000000         125420.000000            1.095972e+07

# %%
Negative.describe()
# Out:
#          state_fips  new_results_reported  total_results_reported
# count  53292.000000          53292.000000            5.329200e+04
# mean      32.329918          16562.140959            7.896541e+06
# std       18.908717          31934.070826            1.492935e+07
# min        1.000000              0.000000            0.000000e+00
# 25%       17.000000           2165.750000            7.657330e+05
# 50%       31.000000           6451.000000            3.032186e+06
# 75%       46.000000          17000.750000            8.788022e+06
# max       78.000000         448238.000000            1.500675e+08

# %%
#Categorical to Onehot Encoding
cat_cols=["new_results_reported", "total_results_reported"]
print(cat_cols)
# Out:
# ['new_results_reported', 'total_results_reported']

# %%
# Create a copy of the data frame in memory with a different name
df_onehot= Negative.copy()

# %%
# Create a copy of the data frame in memory with a different name
df_onehot_1=  Positive.copy()

# %%
df_onehot_2 =Inconclusive.copy()

# %%
#convert only categorical variables/features to dummy/one-hot features
df_onehot = pd.get_dummies(Negative, columns=cat_cols, prefix = cat_cols)
#print the dataset
df_onehot
# Out:
#                 state state_name  state_fips fema_region        date  \
# overall_outcome
# Negative           AL    Alabama           1    Region 4  2020/03/01
# Negative           AL    Alabama           1    Region 4  2020/03/02
# Negative           AL    Alabama           1    Region 4  2020/03/03
# Negative           AL    Alabama           1    Region 4  2020/03/04
# Negative           AL    Alabama           1    Region 4  2020/03/05
# ...               ...        ...         ...         ...         ...
# Negative           WY    Wyoming          56    Region 8  2022/10/16
# Negative           WY    Wyoming          56    Region 8  2022/10/17
# Negative           WY    Wyoming          56    Region 8  2022/10/18
# Negative           WY    Wyoming          56    Region 8  2022/10/19
# Negative           WY    Wyoming          56    Region 8  2022/10/20
#
#                  new_results_reported_0  new_results_reported_1  \
# overall_outcome
# ...

# %%
#convert only categorical variables/features to dummy/one-hot features
df_onehot_1 = pd.get_dummies(Positive, columns=cat_cols, prefix = cat_cols)
#print the dataset
df_onehot_1
# Out:
#                 state state_name  state_fips fema_region        date  \
# overall_outcome
# Positive           AL    Alabama           1    Region 4  2020/03/01
# Positive           AL    Alabama           1    Region 4  2020/03/02
# Positive           AL    Alabama           1    Region 4  2020/03/03
# Positive           AL    Alabama           1    Region 4  2020/03/04
# Positive           AL    Alabama           1    Region 4  2020/03/05
# ...               ...        ...         ...         ...         ...
# Positive           WY    Wyoming          56    Region 8  2022/10/16
# Positive           WY    Wyoming          56    Region 8  2022/10/17
# Positive           WY    Wyoming          56    Region 8  2022/10/18
# Positive           WY    Wyoming          56    Region 8  2022/10/19
# Positive           WY    Wyoming          56    Region 8  2022/10/20
#
#                  new_results_reported_0  new_results_reported_1  \
# overall_outcome
# ...

# %%
#convert only categorical variables/features to dummy/one-hot features
df_onehot_2 = pd.get_dummies(Inconclusive, columns=cat_cols, prefix = cat_cols)
#print the dataset
df_onehot_2
# Out:
#                 state state_name  state_fips fema_region        date  \
# overall_outcome
# Inconclusive       AL    Alabama           1    Region 4  2020/03/13
# Inconclusive       AL    Alabama           1    Region 4  2020/03/14
# Inconclusive       AL    Alabama           1    Region 4  2020/03/15
# Inconclusive       AL    Alabama           1    Region 4  2020/03/16
# Inconclusive       AL    Alabama           1    Region 4  2020/03/17
# ...               ...        ...         ...         ...         ...
# Inconclusive       WY    Wyoming          56    Region 8  2022/10/16
# Inconclusive       WY    Wyoming          56    Region 8  2022/10/17
# Inconclusive       WY    Wyoming          56    Region 8  2022/10/18
# Inconclusive       WY    Wyoming          56    Region 8  2022/10/19
# Inconclusive       WY    Wyoming          56    Region 8  2022/10/20
#
#                  new_results_reported_-7  new_results_reported_-3  \
# overall_outcome
# ...

# %%
#Repeat the train test set split
from sklearn.model_selection import train_test_split

# %%
class_col_name="state_name"
one_hot_feature_names=df_onehot.columns[df_onehot.columns != class_col_name]
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(df_onehot.loc[:, one_hot_feature_names], df_onehot[class_col_name], test_size=0.3,random_state=109) # 70% training and 30% test

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
KNeighborsClassifier()
knn.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cf=confusion_matrix(y_test, y_pred)
print ("Confusion Matrix")
print(cf)
tn, fp, fn, tp=cf.ravel()
print ("TP: ", tp,", FP: ", fp,", TN: ", tn,", FN:", fn)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-0ac6eb31454a> in <module>
#       1 from sklearn.metrics import confusion_matrix
# ----> 2 cf=confusion_matrix(y_test, y_train)
#       3 print ("Confusion Matrix")
#       4 print(cf)
#       5 tn, fp, fn, tp=cf.ravel()
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     305     (0, 2, 1, 1)
#     306     """
# --> 307     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     308     if y_type not in ("binary", "multiclass"):
#     309         raise ValueError("%s is not supported" % y_type)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      82     y_pred : array or indicator matrix
#      83     """
# ...

# %%
from sklearn.metrics import classification_report
from sklearn import metrics

print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-798627bf25e0> in <module>
#       2 from sklearn import metrics
#       3
# ----> 4 print(classification_report(y_test, y_pred))
#
# NameError: name 'y_pred' is not defined

# %%
#for  pcr dataset, we have the following
cat_cols=["new_results_reported", "total_results_reported"]
print(cat_cols)
# Out:
# ['new_results_reported', 'total_results_reported']

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
  
# Filter data between two dates
filtered_df = Negative.loc[(df['date'] >= '2021-03-01')
                     & (df['date'] < '2021-09-15')]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-c4a139a4675d> in <module>
#       3 # Filter data between two dates
#       4 filtered_df = Negative.loc[(df['date'] >= '2021-03-01')
# ----> 5                      & (df['date'] < '2021-09-15')]
#       6
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1142             return self._get_slice_axis(key, axis=axis)
#    1143         elif com.is_bool_indexer(key):
# -> 1144             return self._getbool_axis(key, axis=axis)
# ...
